# %% [markdown]
# ## <center>CITS5508 Lab sheet 2: Classification on...................</center>
#
# **Name: Jordan Makins**<br>
# **Student number: 21317635**<br>
# **Date created:** 11 March 2021<br>
# **Last modified:** March 2021<br>
#
# A brief summary about the work done for this lab sheet...

# %% [markdown]
# ## 1. Heading ....
#
# A brief description about the task for this part ...

# %% [markdown]
# ## 3. Import Packages
#
# There are two main types of cells: *Markdown* and *Code*. A *Markdown* cell is for you to put in formatted comments between *Code* cells to help explain to the reader what is going on in your code. You can double-click on a *Markdown* cell to edit its contents. You can even have complex equations put into a *Markdown* cell, like the example shown below:
#
# $\text{MSE}(\theta) = \frac{1}{m} \sum_{i=1}^m
#                       (h_\theta(\mathbf{x}^{(i)}) - y^{(i)})^2$
#
# Rather than an equation on its own, mathematics symbols can appear in the same paragraph of the text, like here: The regularization coefficient $\alpha$ used in the experiment below is set to 0.5.

# %%
# !pip3 install scipy

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-07d378cf0963> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib as plt
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       4 import matplotlib as mpl
#       5 import warnings
# ----> 6 from . import palettes, _orig_rc_params
#       7
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       8 from .external import husl
#       9
# ---> 10 from .utils import desaturate, set_hls_values, get_color_cycle
# ...

# %%
data = pd.read_excel("Dry_Bean_Dataset.xlsx") # use pandas to load data into Jupyter environment

# %%
data.head() # inspect first few lines of the dataset and all features
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
# Visualize 6 interesting features with a scatter plot
